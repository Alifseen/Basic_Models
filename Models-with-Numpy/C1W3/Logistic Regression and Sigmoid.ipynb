# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data, draw_vthresh
from plt_one_addpt_onclick import plt_one_addpt_onclick

# %%
# %matplotlib widget
plt.style.use("./deeplearning.mplstyle")
np.set_printoptions(precision=3)

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig, ax = plt.subplots(1,2, figsize=(8,3))
ax[0].scatter(x_train[pos], y_train[pos], marker= "x", c="r")
ax[0].scatter(x_train[neg], y_train[neg], marker= "o", c="blue")
plot_data(X_train2, y_train2, ax[1])
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
def sigmoid(z):
    g = 1 / (1 + np.exp(-z))
    return g

# %%
z_temp = np.arange(-10, 11)
y = sigmoid(z_temp)
print(np.c_[z_temp, y])
# Out:
# [[-1.000e+01  4.540e-05]
#  [-9.000e+00  1.234e-04]
#  [-8.000e+00  3.354e-04]
#  [-7.000e+00  9.111e-04]
#  [-6.000e+00  2.473e-03]
#  [-5.000e+00  6.693e-03]
#  [-4.000e+00  1.799e-02]
#  [-3.000e+00  4.743e-02]
#  [-2.000e+00  1.192e-01]
#  [-1.000e+00  2.689e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  7.311e-01]
#  [ 2.000e+00  8.808e-01]
#  [ 3.000e+00  9.526e-01]
#  [ 4.000e+00  9.820e-01]
#  [ 5.000e+00  9.933e-01]
#  [ 6.000e+00  9.975e-01]
#  [ 7.000e+00  9.991e-01]
#  [ 8.000e+00  9.997e-01]
#  [ 9.000e+00  9.999e-01]
#  [ 1.000e+01  1.000e+00]]

# %%
fig, ax = plt.subplots(1,1, figsize=(5,3))
ax.plot(z_temp, y, c="b")
draw_vthresh(ax, 0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")

# %%
xtr = np.array([0., 1, 2, 3, 4, 5])
ytr = np.array([0,  0, 0, 1, 1, 1])

w_in = np.zeros((1))
b_in = 0

plt_one_addpt_onclick(xtr, ytr, w_in, b_in, logistic=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 7
#       4 w_in = np.zeros((1))
#       5 b_in = 0
# ----> 7 plt_one_addpt_onclick(xtr, ytr, w_in, b_in, logistic=True)
#
# File ~/projects/basic_models/Models-with-Numpy/W3/plt_one_addpt_onclick.py:66, in plt_one_addpt_onclick.__init__(self, x, y, w, b, logistic)
#      64 self.bthresh = CheckButtons(axthresh, ('Toggle 0.5 threshold (after regression)',))
#      65 self.bthresh.on_clicked(self.thresh)
# ---> 66 self.resize_sq(self.bthresh)
#
# File ~/projects/basic_models/Models-with-Numpy/W3/plt_one_addpt_onclick.py:179, in plt_one_addpt_onclick.resize_sq(self, bcid)
#     171 """ resizes the check box """
#     172 #future reference
#     173 #print(f"width  : {bcid.rectangles[0].get_width()}")
#     174 #print(f"height : {bcid.rectangles[0].get_height()}")
# ...

# %%
plt.close("all")
